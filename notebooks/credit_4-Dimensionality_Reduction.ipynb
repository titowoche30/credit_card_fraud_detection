# %% [markdown]
# # Kaggle Dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# # Details: https://scikit-learn.org/stable/modules/decomposition.html#decompositions and https://scikit-learn.org/stable/modules/neighbors.html#nca

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import time

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import IncrementalPCA
from sklearn.metrics import precision_recall_curve, auc
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.decomposition import TruncatedSVD
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from joblib import dump,load

# %%
##df = pd.read_csv('../data/creditcard.csv')
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#(clf, X, y_true)
def auc_score(model,X_test,y_test):
    y_test_pred = model.predict_proba(X_test)
    precision, recall, thresholds = precision_recall_curve(y_test, y_test_pred[:,1])
    return auc(recall, precision)

# %%
def auc_score_2(model,X_test,y_test):
    y_test_pred = model.decision_function(X_test)
    avg =  average_precision_score(y_test, y_test_pred)
    return avg

# %%
dict_classifiers = {
    'KNeighbors': KNeighborsClassifier(n_jobs=3),
    "Random Forest": RandomForestClassifier(random_state=42, n_jobs=3),
    "Logistic": LogisticRegression(solver='liblinear'),
    'Stochastic GD': SGDClassifier(loss='log',n_jobs=3, random_state=42,fit_intercept=False),
    'LinearSVM': LinearSVC(dual=False),
}
classifiers_names = list(dict_classifiers.keys())
classifiers_values = list(dict_classifiers.values())

# %% [markdown]
# # PCA

# %%
t0 = time.time()
print('PCA')
X = df.drop(['Time','Class'],axis=1)
y = df['Class']

scoring_parameters = [auc_score] *4 + [auc_score_2]
scores = []
for i in range(2,X.shape[1]):
    print('\t\t'+'----'*8+f'{i} components'+'----'*8)
    X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33,random_state=42)

    for name,model,scorer in zip(classifiers_names,classifiers_values,scoring_parameters):
        print('--'*6+f'{name}'+'--'*6)
        scaler = StandardScaler()
        batch_size = 14000
        pca=IncrementalPCA(batch_size=batch_size,n_components=i)

        pipe = Pipeline([('scaler',scaler),
                        ('pca',pca),
                        ('model',model)])

        pipe.fit(X_train,y_train)

        score = scorer(pipe,X_test,y_test)
        scores.append(score)
        print('auc =',score)

print('total time taken:',time.time()-t0)
# Out:
# 		--------------------------------2 components--------------------------------
# ------------KNeighbors------------
# auc = 0.10920010240566828
# ------------Random Forest------------
# auc = 0.19634796466816293
# ------------Logistic------------
# auc = 0.2002615995901772
# ------------Stochastic GD------------
# auc = 0.014141523562877545
# ------------LinearSVM------------
# auc = 0.21347728840014685
# 		--------------------------------3 components--------------------------------
# ------------KNeighbors------------
# auc = 0.803611778353889
# ------------Random Forest------------
# auc = 0.7817319060914081
# ------------Logistic------------
# auc = 0.7213077461167079
# ------------Stochastic GD------------
# auc = 0.04170971673325553
# ------------LinearSVM------------
# auc = 0.7232027730714097
# 		--------------------------------4 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8408332328183362
# ------------Random Forest------------
# auc = 0.8143551548347319
# ------------Logistic------------
# auc = 0.7178832530500369
# ------------Stochastic GD------------
# auc = 0.716704592178162
# ------------LinearSVM------------
# auc = 0.7242294758943643
# 		--------------------------------5 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8430211396102762
# ------------Random Forest------------
# auc = 0.8255354529508646
# ------------Logistic------------
# auc = 0.7258318709873898
# ------------Stochastic GD------------
# auc = 0.7250013867789257
# ------------LinearSVM------------
# auc = 0.7315227362034961
# 		--------------------------------6 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8446022687869772
# ------------Random Forest------------
# auc = 0.824721899192072
# ------------Logistic------------
# auc = 0.7310325947600177
# ------------Stochastic GD------------
# auc = 0.7264492038466228
# ------------LinearSVM------------
# auc = 0.7305767353671699
# 		--------------------------------7 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8449919637558863
# ------------Random Forest------------
# auc = 0.8238130698898867
# ------------Logistic------------
# auc = 0.7264389871766721
# ------------Stochastic GD------------
# auc = 0.506166360514991
# ------------LinearSVM------------
# auc = 0.730992474004385
# 		--------------------------------8 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8562270507993981
# ------------Random Forest------------
# auc = 0.8328377230829114
# ------------Logistic------------
# auc = 0.7326568035876451
# ------------Stochastic GD------------
# auc = 0.45260254464606275
# ------------LinearSVM------------
# auc = 0.740729057123564
# 		--------------------------------9 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8593284697947385
# ------------Random Forest------------
# auc = 0.8311193888821526
# ------------Logistic------------
# auc = 0.7300402488148524
# ------------Stochastic GD------------
# auc = 0.4269214328003962
# ------------LinearSVM------------
# auc = 0.7404050195238128
# 		--------------------------------10 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8578376477593709
# ------------Random Forest------------
# auc = 0.8322698069568047
# ------------Logistic------------
# auc = 0.7220185589540635
# ------------Stochastic GD------------
# auc = 0.43152788106414003
# ------------LinearSVM------------
# auc = 0.7425072715732328
# 		--------------------------------11 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8603295073803353
# ------------Random Forest------------
# auc = 0.8387868193221711
# ------------Logistic------------
# auc = 0.7207254326270847
# ------------Stochastic GD------------
# auc = 0.43494353272484165
# ------------LinearSVM------------
# auc = 0.739722837269943
# 		--------------------------------12 components--------------------------------
# ------------KNeighbors------------
# auc = 0.865750168445844
# ------------Random Forest------------
# auc = 0.8374220776232103
# ------------Logistic------------
# auc = 0.7213914863310328
# ------------Stochastic GD------------
# auc = 0.46487256281258904
# ------------LinearSVM------------
# auc = 0.7398910927127916
# 		--------------------------------13 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8646153132414154
# ------------Random Forest------------
# auc = 0.8433837608588424
# ------------Logistic------------
# auc = 0.7350276040143267
# ------------Stochastic GD------------
# auc = 0.5121108383366115
# ------------LinearSVM------------
# auc = 0.7526751177162836
# 		--------------------------------14 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8783195401741648
# ------------Random Forest------------
# auc = 0.8452719106083928
# ------------Logistic------------
# auc = 0.7541249022267562
# ------------Stochastic GD------------
# auc = 0.5077339027017073
# ------------LinearSVM------------
# auc = 0.7594783750804215
# 		--------------------------------15 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8845923814460563
# ------------Random Forest------------
# auc = 0.8502673576499321
# ------------Logistic------------
# auc = 0.7566745427764636
# ------------Stochastic GD------------
# auc = 0.5264913419646297
# ------------LinearSVM------------
# auc = 0.7610751173798056
# 		--------------------------------16 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8736675200949319
# ------------Random Forest------------
# auc = 0.8529057943760906
# ------------Logistic------------
# auc = 0.7618364284866508
# ------------Stochastic GD------------
# auc = 0.5634680043347723
# ------------LinearSVM------------
# auc = 0.7648771007897202
# 		--------------------------------17 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8812868050565422
# ------------Random Forest------------
# auc = 0.8612131763842392
# ------------Logistic------------
# auc = 0.7662242372816318
# ------------Stochastic GD------------
# auc = 0.5583029139696305
# ------------LinearSVM------------
# auc = 0.7709582949804059
# 		--------------------------------18 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8775004356309478
# ------------Random Forest------------
# auc = 0.8421143753368321
# ------------Logistic------------
# auc = 0.7715889483957268
# ------------Stochastic GD------------
# auc = 0.7153839034803805
# ------------LinearSVM------------
# auc = 0.7823869109680394
# 		--------------------------------19 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8807033850542848
# ------------Random Forest------------
# auc = 0.8554846645541878
# ------------Logistic------------
# auc = 0.7715109387010646
# ------------Stochastic GD------------
# auc = 0.7173359232312189
# ------------LinearSVM------------
# auc = 0.7828706344393237
# 		--------------------------------20 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8805523177884265
# ------------Random Forest------------
# auc = 0.8522123950026574
# ------------Logistic------------
# auc = 0.7751609298009573
# ------------Stochastic GD------------
# auc = 0.7211434686570664
# ------------LinearSVM------------
# auc = 0.7846483636756156
# 		--------------------------------21 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8702899756820914
# ------------Random Forest------------
# auc = 0.8585095229690964
# ------------Logistic------------
# auc = 0.7747541076523945
# ------------Stochastic GD------------
# auc = 0.7210647791276819
# ------------LinearSVM------------
# auc = 0.7832166669067494
# 		--------------------------------22 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8740748053112006
# ------------Random Forest------------
# auc = 0.8549338650487245
# ------------Logistic------------
# auc = 0.7738120431758218
# ------------Stochastic GD------------
# auc = 0.7159209544228103
# ------------LinearSVM------------
# auc = 0.7836401226055578
# 		--------------------------------23 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8769287415712808
# ------------Random Forest------------
# auc = 0.8484221682914336
# ------------Logistic------------
# auc = 0.7746105224927149
# ------------Stochastic GD------------
# auc = 0.7152618151254674
# ------------LinearSVM------------
# auc = 0.7846769775004845
# 		--------------------------------24 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8757505362801099
# ------------Random Forest------------
# auc = 0.8406778836923587
# ------------Logistic------------
# auc = 0.7738662072992992
# ------------Stochastic GD------------
# auc = 0.7154997856909703
# ------------LinearSVM------------
# auc = 0.7847459605648338
# 		--------------------------------25 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8694588975657888
# ------------Random Forest------------
# auc = 0.8265545338784541
# ------------Logistic------------
# auc = 0.7744259060834465
# ------------Stochastic GD------------
# auc = 0.7143696056414052
# ------------LinearSVM------------
# auc = 0.7868762432237001
# 		--------------------------------26 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8674140045116847
# ------------Random Forest------------
# auc = 0.8577451827155218
# ------------Logistic------------
# auc = 0.7883036541084049
# ------------Stochastic GD------------
# auc = 0.7344906843076539
# ------------LinearSVM------------
# auc = 0.7963023995477081
# 		--------------------------------27 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8670267423888589
# ------------Random Forest------------
# auc = 0.8411777452908084
# ------------Logistic------------
# auc = 0.7874861847216893
# ------------Stochastic GD------------
# auc = 0.7421089659452812
# ------------LinearSVM------------
# auc = 0.7967522459238879
# 		--------------------------------28 components--------------------------------
# ------------KNeighbors------------
# auc = 0.8673314770853167
# ------------Random Forest------------
# auc = 0.8529541276683843
# ------------Logistic------------
# auc = 0.7873253347122733
# ------------Stochastic GD------------
# auc = 0.7426562201288989
# ------------LinearSVM------------
# auc = 0.7968420991557587

# %%
scores = np.array(scores).reshape(27,5).T
columns = [str(i)+ ' columns' for i in list(range(2,X.shape[1]))]
scores_df_pca = pd.DataFrame(scores,index=classifiers_names,columns=columns)

# %%
#Max of each classifier and which column
print(scores_df_pca.max(axis=1),'\n')
print(scores_df_pca.idxmax(axis=1))
# Out:
# KNeighbors       0.884592
# Random Forest    0.861213
# Logistic         0.788304
# Stochastic GD    0.742656
# LinearSVM        0.796842
# dtype: float64
#
# KNeighbors       15 columns
# Random Forest    17 columns
# Logistic         26 columns
# Stochastic GD    28 columns
# LinearSVM        28 columns
# dtype: object

# %%
plt.figure(figsize=(14,12))
plt.title('Estimators used in PCA',size='xx-large')
plt.xlabel('Number of Columns',size='xx-large')
plt.xticks(size='x-large')
plt.ylabel('AUC',size='xx-large')
plt.yticks(size='x-large')
x = range(2,29)
plt.plot(x,scores_df_pca.loc['KNeighbors'].values,label='KNeighbors',marker='p',ms=8)
plt.plot(x,scores_df_pca.loc['Random Forest'].values,label='Random Forest',marker='v',ms=8)
plt.plot(x,scores_df_pca.loc['Logistic'].values,label='Logistic',marker='^',ms=8)
plt.plot(x,scores_df_pca.loc['LinearSVM'].values,label='LinearSVM',marker='o',ms=8)
plt.plot(x,scores_df_pca.loc['Stochastic GD'].values,label='Stochastic GD',marker='s',ms=8)
plt.legend(loc='center right',frameon=True,title='Estimator',title_fontsize='xx-large',fontsize='x-large',edgecolor='black')
plt.show()

# %%
# The main aim of PCA while reducing dataset itself is to restore as much variance of data is possible.
# Each eigenvector is associated with its eigenvalue which shows how much data is spread along that component (eigenvector).
# Hence will try to choose those vectors which are restoring 0.01(99%) of the variance of the original dataset
pca = pipe.named_steps['pca']
plt.figure(figsize=(10,10))
plt.title('Explained Variance')
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') 
plt.plot(np.cumsum(pca.explained_variance_ratio_),marker='o')
plt.axhline(y=0.99,c='black')
plt.show()

# %% [markdown]
# ### Since PCA had been already applied to the dataset, this results make sense

# %%
#check: https://stackoverflow.com/questions/50796024/feature-variable-importance-after-a-pca-analysis
#The important features are the ones that influence more the components and thus,
#have a large absolute value/score on the component(eigenvector).

n_pcs = pca.components_.shape[0]

# get the index of the most important feature on EACH component
most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]

initial_feature_names = X_train.columns
# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]

dic = {'PC{}'.format(i): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
# each feature impacts each PC(eigenvector) diferently
df_pca = pd.DataFrame(dic.items())
df_pca
# Out:
#        0       1
# 0    PC0  Amount
# 1    PC1     V20
# 2    PC2      V2
# 3    PC3     V23
# 4    PC4      V8
# 5    PC5     V17
# 6    PC6     V16
# 7    PC7     V24
# 8    PC8     V24
# 9    PC9     V10
# 10  PC10     V16
# 11  PC11     V26
# 12  PC12     V13
# 13  PC13     V12
# 14  PC14     V18
# 15  PC15      V1
# 16  PC16     V11
# 17  PC17     V24
# 18  PC18     V11
# 19  PC19     V12
# 20  PC20     V25
# 21  PC21     V25
# 22  PC22      V6
# 23  PC23      V2
# 24  PC24     V27
# 25  PC25     V21
# 26  PC26     V28
# 27  PC27      V7

# %%
df_pca[1].value_counts()
# Out:
# V24       3
# V12       2
# V25       2
# V11       2
# V16       2
# V2        2
# V27       1
# V6        1
# V17       1
# V18       1
# V26       1
# V28       1
# Amount    1
# V13       1
# V7        1
# V23       1
# V8        1
# V21       1
# V10       1
# V1        1
# V20       1
# Name: 1, dtype: int64

# %%
top_features = df_pca[1].value_counts().keys()
top_values = df_pca[1].value_counts().values
plt.figure(figsize=(10,10))
plt.title('Feature Importances')
plt.barh(top_features, top_values)
plt.xticks(list(range(4)))
plt.yticks(top_features)
plt.show()

# %% [markdown]
# # Truncated SVD

# %%
scoring_parameters = [auc_score] *4 + [auc_score_2]

X = df.drop(['Time','Class'],axis=1)
y = df['Class']
scores = []

print('Truncated SVD')
t0 = time.time()
for i in range (2,X.shape[1]):
    print('----'*8+f'{i} components'+'----'*8)
    X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33,random_state=42)

    for name,model,scorer in zip(classifiers_names,classifiers_values,scoring_parameters):
        print('----'*4+f'{name}'+'----'*4)
        scaler = StandardScaler()
        svd = TruncatedSVD(n_components=i,random_state=42)

        svd_pipe = Pipeline([('scaler',scaler),
                             ('svd',svd)])

        X_train_transformed=svd_pipe.fit_transform(X_train,y_train)
        X_test_transformed=svd_pipe.transform(X_test)

        model.fit(X_train_transformed,y_train)
        score = scorer(model,X_test_transformed,y_test)
        scores.append(score)
        print('auc =',score)


print('total time taken:',time.time()-t0)
# Out:
# Truncated SVD
# --------------------------------2 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.026029307072487493
# ----------------Random Forest----------------
# auc = 0.03274725301429002
# ----------------Logistic----------------
# auc = 0.01640041337926275
# ----------------Stochastic GD----------------
# auc = 0.0038535683326669664
# ----------------LinearSVM----------------
# auc = 0.01285336331682016
# --------------------------------3 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.28093331750761735
# ----------------Random Forest----------------
# auc = 0.33825788798320977
# ----------------Logistic----------------
# auc = 0.08316514827208692
# ----------------Stochastic GD----------------
# auc = 0.00909943238546633
# ----------------LinearSVM----------------
# auc = 0.0990974644789685
# --------------------------------4 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.5528577430024697
# ----------------Random Forest----------------
# auc = 0.5728965497937413
# ----------------Logistic----------------
# auc = 0.31462859076936434
# ----------------Stochastic GD----------------
# auc = 0.11109561245263755
# ----------------LinearSVM----------------
# auc = 0.31180936658251074
# --------------------------------5 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.4867196968785838
# ----------------Random Forest----------------
# auc = 0.5103889179863867
# ----------------Logistic----------------
# auc = 0.1652687652846927
# ----------------Stochastic GD----------------
# auc = 0.005014644513163498
# ----------------LinearSVM----------------
# auc = 0.15456790428195377
# --------------------------------6 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.761863162339998
# ----------------Random Forest----------------
# auc = 0.7764974414510276
# ----------------Logistic----------------
# auc = 0.6438867154600799
# ----------------Stochastic GD----------------
# auc = 0.004475604348711391
# ----------------LinearSVM----------------
# auc = 0.6377826671159306
# --------------------------------7 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.7861637517034843
# ----------------Random Forest----------------
# auc = 0.7481574452082677
# ----------------Logistic----------------
# auc = 0.5482939323103382
# ----------------Stochastic GD----------------
# auc = 0.32708314388941656
# ----------------LinearSVM----------------
# auc = 0.5664070870034977
# --------------------------------8 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.7876024621293116
# ----------------Random Forest----------------
# auc = 0.78979644521519
# ----------------Logistic----------------
# auc = 0.6505033692196279
# ----------------Stochastic GD----------------
# auc = 0.011472807190148985
# ----------------LinearSVM----------------
# auc = 0.6634351439274956
# --------------------------------9 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8171601099825123
# ----------------Random Forest----------------
# auc = 0.8434958771023919
# ----------------Logistic----------------
# auc = 0.651441107243027
# ----------------Stochastic GD----------------
# auc = 0.004074795370974618
# ----------------LinearSVM----------------
# auc = 0.683150956090123
# --------------------------------10 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8108634401303159
# ----------------Random Forest----------------
# auc = 0.8102474075822721
# ----------------Logistic----------------
# auc = 0.6605966846361755
# ----------------Stochastic GD----------------
# auc = 0.05521346361525751
# ----------------LinearSVM----------------
# auc = 0.6844609872556523
# --------------------------------11 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8358526787625697
# ----------------Random Forest----------------
# auc = 0.8301947461191865
# ----------------Logistic----------------
# auc = 0.6868784556595193
# ----------------Stochastic GD----------------
# auc = 0.0100324330208178
# ----------------LinearSVM----------------
# auc = 0.69413182698302
# --------------------------------12 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8056465029129664
# ----------------Random Forest----------------
# auc = 0.7985482057569403
# ----------------Logistic----------------
# auc = 0.6295944704850975
# ----------------Stochastic GD----------------
# auc = 0.005861174637086812
# ----------------LinearSVM----------------
# auc = 0.6587932389968221
# --------------------------------13 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8335313963363263
# ----------------Random Forest----------------
# auc = 0.8210383518592206
# ----------------Logistic----------------
# auc = 0.728350556320988
# ----------------Stochastic GD----------------
# auc = 0.0035269313985017694
# ----------------LinearSVM----------------
# auc = 0.737357511879106
# --------------------------------14 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8277292459727132
# ----------------Random Forest----------------
# auc = 0.8288225493512243
# ----------------Logistic----------------
# auc = 0.7139896743581106
# ----------------Stochastic GD----------------
# auc = 0.004181991594473295
# ----------------LinearSVM----------------
# auc = 0.7260700120093816
# --------------------------------15 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8352750114972586
# ----------------Random Forest----------------
# auc = 0.825198240094076
# ----------------Logistic----------------
# auc = 0.7279093670586629
# ----------------Stochastic GD----------------
# auc = 0.4066345436194654
# ----------------LinearSVM----------------
# auc = 0.7380488286404185
# --------------------------------16 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8344667574794059
# ----------------Random Forest----------------
# auc = 0.831657382245903
# ----------------Logistic----------------
# auc = 0.7365137200826182
# ----------------Stochastic GD----------------
# auc = 0.0031080478009073596
# ----------------LinearSVM----------------
# auc = 0.7455617090200535
# --------------------------------17 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8374933640781691
# ----------------Random Forest----------------
# auc = 0.8543081147757967
# ----------------Logistic----------------
# auc = 0.7445452455224563
# ----------------Stochastic GD----------------
# auc = 0.004250439794820314
# ----------------LinearSVM----------------
# auc = 0.7509572450794542
# --------------------------------18 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8354676697310763
# ----------------Random Forest----------------
# auc = 0.8461878211654896
# ----------------Logistic----------------
# auc = 0.744769740970293
# ----------------Stochastic GD----------------
# auc = 0.4462464244928632
# ----------------LinearSVM----------------
# auc = 0.756351814460857
# --------------------------------19 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8395879449639707
# ----------------Random Forest----------------
# auc = 0.8503381962349691
# ----------------Logistic----------------
# auc = 0.745475392016544
# ----------------Stochastic GD----------------
# auc = 0.436226039111026
# ----------------LinearSVM----------------
# auc = 0.7554684351342439
# --------------------------------20 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8449050013600323
# ----------------Random Forest----------------
# auc = 0.845799517699622
# ----------------Logistic----------------
# auc = 0.7495130496786906
# ----------------Stochastic GD----------------
# auc = 0.42992741142118446
# ----------------LinearSVM----------------
# auc = 0.758486447120839
# --------------------------------21 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8495333482787527
# ----------------Random Forest----------------
# auc = 0.8481511841016897
# ----------------Logistic----------------
# auc = 0.7517866032832419
# ----------------Stochastic GD----------------
# auc = 0.43314759736978636
# ----------------LinearSVM----------------
# auc = 0.7626914872604611
# --------------------------------22 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8471468338118326
# ----------------Random Forest----------------
# auc = 0.8532896060631912
# ----------------Logistic----------------
# auc = 0.7523163595870239
# ----------------Stochastic GD----------------
# auc = 0.46193975466888854
# ----------------LinearSVM----------------
# auc = 0.7658413995330183
# --------------------------------23 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8539299297686683
# ----------------Random Forest----------------
# auc = 0.849779761718422
# ----------------Logistic----------------
# auc = 0.7524276606392778
# ----------------Stochastic GD----------------
# auc = 0.489920046592474
# ----------------LinearSVM----------------
# auc = 0.7649733411887445
# --------------------------------24 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8560349057248475
# ----------------Random Forest----------------
# auc = 0.8630895913571868
# ----------------Logistic----------------
# auc = 0.7628847350956112
# ----------------Stochastic GD----------------
# auc = 0.593740023909612
# ----------------LinearSVM----------------
# auc = 0.7687465571191812
# --------------------------------25 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8593634659927462
# ----------------Random Forest----------------
# auc = 0.8592496540958514
# ----------------Logistic----------------
# auc = 0.7713210747803604
# ----------------Stochastic GD----------------
# auc = 0.6026211177110827
# ----------------LinearSVM----------------
# auc = 0.7825705908591379
# --------------------------------26 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8608569403781974
# ----------------Random Forest----------------
# auc = 0.8452243611756476
# ----------------Logistic----------------
# auc = 0.77370870965931
# ----------------Stochastic GD----------------
# auc = 0.4467849332830619
# ----------------LinearSVM----------------
# auc = 0.7883964010976497
# --------------------------------27 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8651711776531713
# ----------------Random Forest----------------
# auc = 0.8523287053362095
# ----------------Logistic----------------
# auc = 0.7747904707280743
# ----------------Stochastic GD----------------
# auc = 0.3636919667856615
# ----------------LinearSVM----------------
# auc = 0.7906426703673856
# --------------------------------28 components--------------------------------
# ----------------KNeighbors----------------
# auc = 0.8673314770853167
# ----------------Random Forest----------------
# auc = 0.8547946253665518
# ----------------Logistic----------------
# auc = 0.7873230540668641
# ----------------Stochastic GD----------------
# auc = 0.7426573250447528
# ----------------LinearSVM----------------
# auc = 0.7968420967210343
# total time taken: 5725.153962612152

# %%
scores = np.array(scores).reshape(27,5).T
columns = [str(i)+ ' columns' for i in list(range(2,X.shape[1]))]
scores_df_svd = pd.DataFrame(scores,index=classifiers_names,columns=columns)

# %%
#Max of each classifier and which column
print(scores_df_svd.max(axis=1),'\n')
print(scores_df_svd.idxmax(axis=1))
# Out:
# KNeighbors       0.867331
# Random Forest    0.863090
# Logistic         0.787323
# Stochastic GD    0.742657
# LinearSVM        0.796842
# dtype: float64
#
# KNeighbors       28 columns
# Random Forest    24 columns
# Logistic         28 columns
# Stochastic GD    28 columns
# LinearSVM        28 columns
# dtype: object

# %%
plt.figure(figsize=(14,12))
plt.title('Estimators used in SVD',size='xx-large')
plt.xlabel('Number of Columns',size='xx-large')
plt.xticks(size='x-large')
plt.ylabel('AUC',size='xx-large')
plt.yticks(size='x-large')
x = range(2,29)
plt.plot(x,scores_df_svd.loc['KNeighbors'].values,label='KNeighbors',marker='p',ms=8)
plt.plot(x,scores_df_svd.loc['Random Forest'].values,label='Random Forest',marker='v',ms=8)
plt.plot(x,scores_df_svd.loc['Logistic'].values,label='Logistic',marker='^',ms=8)
plt.plot(x,scores_df_svd.loc['LinearSVM'].values,label='LinearSVM',marker='o',ms=8)
plt.plot(x,scores_df_svd.loc['Stochastic GD'].values,label='Stochastic GD',marker='s',ms=8)
plt.legend(loc='center right',frameon=True,title='Estimator',title_fontsize='xx-large',fontsize='x-large',edgecolor='black')
plt.show()

# %% [markdown]
# # NCA

# %% [markdown]
# ### I've tested NCA in google colab cause it takes a lot of RAM and time even using batches

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/creditcard.csv')
X = df.drop(['Time'],axis=1)
y = df['Class']
chunksize = 14000
scoring_parameters = [auc_score] *4 + [auc_score_2]
scores = []
t0 = time.time()
for i in range(2,X.shape[0]+1):
    df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/creditcard.csv')
    print('\t\t'+'----'*6+f'{i} components'+'----'*6)
    X = df.drop(['Time'],axis=1)
    y = df['Class']
    nca = NeighborhoodComponentsAnalysis(random_state=42,n_components=i)

    X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33,random_state=42)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)
    list_df = [X_train.loc[i:i+chunksize-1,:] for i in range(0,X_train.shape[0],chunksize)]

    for df in list_df:
            df_train=df.pop('Class')
            #nca_pipe = Pipeline([('scaler', scaler),('nca', nca)])
            #nca_pipe.fit(df,df_train)
            scaler = StandardScaler()
            nca_pipe = Pipeline([('scaler',scaler),
                            ('nca',nca)])

            nca_pipe.fit(df,df_train)
            nca_pipe.named_steps['nca'].set_params(warm_start=True)
            
    X_test = X_test.drop(['Class'],axis=1)
    X_train = X_train.drop(['Class'],axis=1)
    X_train_transformed=nca_pipe.transform(X_train)
    X_test_transformed=nca_pipe.transform(X_test)

    for name,model,scorer in zip(classifiers_names,classifiers_values,scoring_parameters):
        print('----'*4+f'{name}'+'----'*4)
        model.fit(X_train_transformed,y_train)
        score = scorer(model,X_test_transformed,y_test)
        scores.append(score)
        print('auc =',score)

        

print('total time taken:',time.time()-t0)
# Out:
# 		------------------------2 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8568091381460959
# ----------------Random Forest----------------
# auc = 0.8444590494610573
# ----------------Logistic----------------
# auc = 0.752128456968615
# ----------------Stochastic GD----------------
# auc = 0.7486992598879917
# ----------------LinearSVM----------------
# auc = 0.7604125831153313
# 		------------------------3 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8246909844981793
# ----------------Random Forest----------------
# auc = 0.8194135738312053
# ----------------Logistic----------------
# auc = 0.7478356103930568
# ----------------Stochastic GD----------------
# auc = 0.5699919537062981
# ----------------LinearSVM----------------
# auc = 0.7576412835124551
# 		------------------------4 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8581367265704991
# ----------------Random Forest----------------
# auc = 0.8397586533698455
# ----------------Logistic----------------
# auc = 0.7485286953894212
# ----------------Stochastic GD----------------
# auc = 0.6551407731754988
# ----------------LinearSVM----------------
# auc = 0.7565550473150332
# 		------------------------5 components------------------------
# ----------------KNeighbors----------------
# auc = 0.852372775249166
# ----------------Random Forest----------------
# auc = 0.8244701989836333
# ----------------Logistic----------------
# auc = 0.6585353750077438
# ----------------Stochastic GD----------------
# auc = 0.4015522718666243
# ----------------LinearSVM----------------
# auc = 0.7020348133126914
# 		------------------------6 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8128891344797892
# ----------------Random Forest----------------
# auc = 0.8104420118051001
# ----------------Logistic----------------
# auc = 0.7038648188879194
# ----------------Stochastic GD----------------
# auc = 0.0074019676812843065
# ----------------LinearSVM----------------
# auc = 0.7191522487990312
# 		------------------------7 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8683372934168994
# ----------------Random Forest----------------
# auc = 0.8315552173558449
# ----------------Logistic----------------
# auc = 0.738682562744936
# ----------------Stochastic GD----------------
# auc = 0.002002101658240255
# ----------------LinearSVM----------------
# auc = 0.7716513672679578
# 		------------------------8 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8518224465021861
# ----------------Random Forest----------------
# auc = 0.8169304236874539
# ----------------Logistic----------------
# auc = 0.7367576269137753
# ----------------Stochastic GD----------------
# auc = 0.0008286708826947332
# ----------------LinearSVM----------------
# auc = 0.7475408734165614
# 		------------------------9 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8658223275386019
# ----------------Random Forest----------------
# auc = 0.8559626078809764
# ----------------Logistic----------------
# auc = 0.763803759165287
# ----------------Stochastic GD----------------
# auc = 0.7009467959668129
# ----------------LinearSVM----------------
# auc = 0.7712338204387853
# 		------------------------10 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8630427219020206
# ----------------Random Forest----------------
# auc = 0.860973535348621
# ----------------Logistic----------------
# auc = 0.7586212739674086
# ----------------Stochastic GD----------------
# auc = 0.7086959818995016
# ----------------LinearSVM----------------
# auc = 0.7652578420394939
# 		------------------------11 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8687614650954208
# ----------------Random Forest----------------
# auc = 0.8479711177807332
# ----------------Logistic----------------
# auc = 0.7582545200589429
# ----------------Stochastic GD----------------
# auc = 0.6921941480684809
# ----------------LinearSVM----------------
# auc = 0.7646770959343706
# 		------------------------12 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8579573295924323
# ----------------Random Forest----------------
# auc = 0.8326362082699119
# ----------------Logistic----------------
# auc = 0.773273764966392
# ----------------Stochastic GD----------------
# auc = 0.3749959517132335
# ----------------LinearSVM----------------
# auc = 0.784180922709261
# 		------------------------13 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8671309524071935
# ----------------Random Forest----------------
# auc = 0.8392076612201683
# ----------------Logistic----------------
# auc = 0.7774814483080205
# ----------------Stochastic GD----------------
# auc = 0.7588546036240907
# ----------------LinearSVM----------------
# auc = 0.7823250571497488
# 		------------------------14 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8847557229327877
# ----------------Random Forest----------------
# auc = 0.8633399215946919
# ----------------Logistic----------------
# auc = 0.7487492463403249
# ----------------Stochastic GD----------------
# auc = 0.6691244975633676
# ----------------LinearSVM----------------
# auc = 0.7642080129971324
# 		------------------------15 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8839638694682023
# ----------------Random Forest----------------
# auc = 0.859548661233897
# ----------------Logistic----------------
# auc = 0.7755745613688417
# ----------------Stochastic GD----------------
# auc = 0.7040593149904709
# ----------------LinearSVM----------------
# auc = 0.7853048106041117
# 		------------------------16 components------------------------
# ----------------KNeighbors----------------
# auc = 0.87412829849717
# ----------------Random Forest----------------
# auc = 0.8262297022397659
# ----------------Logistic----------------
# auc = 0.7010956300219756
# ----------------Stochastic GD----------------
# auc = 0.014112204792613754
# ----------------LinearSVM----------------
# auc = 0.7270059453785088
# 		------------------------17 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8625898602941882
# ----------------Random Forest----------------
# auc = 0.8373607912765237
# ----------------Logistic----------------
# auc = 0.7757317306424055
# ----------------Stochastic GD----------------
# auc = 0.24278702608549171
# ----------------LinearSVM----------------
# auc = 0.7815010615660262
# 		------------------------18 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8625117120364997
# ----------------Random Forest----------------
# auc = 0.8344899735600981
# ----------------Logistic----------------
# auc = 0.7328886374406064
# ----------------Stochastic GD----------------
# auc = 0.5367587165652599
# ----------------LinearSVM----------------
# auc = 0.7326529786529078
# 		------------------------19 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8723571749381804
# ----------------Random Forest----------------
# auc = 0.8400853412838
# ----------------Logistic----------------
# auc = 0.7823355038384517
# ----------------Stochastic GD----------------
# auc = 0.7248781323297091
# ----------------LinearSVM----------------
# auc = 0.7833746065844536
# 		------------------------20 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8380111177516376
# ----------------Random Forest----------------
# auc = 0.8418093032268965
# ----------------Logistic----------------
# auc = 0.7838984954448346
# ----------------Stochastic GD----------------
# auc = 0.7182678032741922
# ----------------LinearSVM----------------
# auc = 0.7907161762749862
# 		------------------------21 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8554666889348543
# ----------------Random Forest----------------
# auc = 0.8516945215657374
# ----------------Logistic----------------
# auc = 0.7869239672371221
# ----------------Stochastic GD----------------
# auc = 0.40490301453332467
# ----------------LinearSVM----------------
# auc = 0.7899176781429113
# 		------------------------22 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8465511151902987
# ----------------Random Forest----------------
# auc = 0.846307851696645
# ----------------Logistic----------------
# auc = 0.7526824694263652
# ----------------Stochastic GD----------------
# auc = 0.71444330330871
# ----------------LinearSVM----------------
# auc = 0.7726401686206635
# 		------------------------23 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8828940694757014
# ----------------Random Forest----------------
# auc = 0.8384650955262994
# ----------------Logistic----------------
# auc = 0.7728398674300913
# ----------------Stochastic GD----------------
# auc = 0.751178316597869
# ----------------LinearSVM----------------
# auc = 0.7848226498297878
# 		------------------------24 components------------------------

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/creditcard.csv')
X = df.drop(['Time'],axis=1)
y = df['Class']
chunksize = 14000
scoring_parameters = [auc_score] *4 + [auc_score_2]
scores = []
t0 = time.time()
for i in range(24,X.shape[0]):
    df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/creditcard.csv')
    print('\t\t'+'----'*6+f'{i} components'+'----'*6)
    X = df.drop(['Time'],axis=1)
    y = df['Class']
    nca = NeighborhoodComponentsAnalysis(random_state=42,n_components=i)

    X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33,random_state=42)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)
    list_df = [X_train.loc[i:i+chunksize-1,:] for i in range(0,X_train.shape[0],chunksize)]

    for df in list_df:
            df_train=df.pop('Class')
            #nca_pipe = Pipeline([('scaler', scaler),('nca', nca)])
            #nca_pipe.fit(df,df_train)
            scaler = StandardScaler()
            nca_pipe = Pipeline([('scaler',scaler),
                            ('nca',nca)])

            nca_pipe.fit(df,df_train)
            nca_pipe.named_steps['nca'].set_params(warm_start=True)
            
    X_test = X_test.drop(['Class'],axis=1)
    X_train = X_train.drop(['Class'],axis=1)
    X_train_transformed=nca_pipe.transform(X_train)
    X_test_transformed=nca_pipe.transform(X_test)

    for name,model,scorer in zip(classifiers_names,classifiers_values,scoring_parameters):
        print('----'*4+f'{name}'+'----'*4)
        model.fit(X_train_transformed,y_train)
        score = scorer(model,X_test_transformed,y_test)
        scores.append(score)
        print('auc =',score)

        
    #if i==2: dump(nca_pipe, '/content/drive/My Drive/Colab Notebooks/data/nca_pipe2.pkl', compress = 1)

print('total time taken:',time.time()-t0)
# Out:
# 		------------------------24 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8480104434873307
# ----------------Random Forest----------------
# auc = 0.8272353169881494
# ----------------Logistic----------------
# auc = 0.7834409312033183
# ----------------Stochastic GD----------------
# auc = 0.7167756131389663
# ----------------LinearSVM----------------
# auc = 0.7926421033271691
# 		------------------------25 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8528397841727129
# ----------------Random Forest----------------
# auc = 0.8397922208825368
# ----------------Logistic----------------
# auc = 0.7835758148248544
# ----------------Stochastic GD----------------
# auc = 0.6862962908715456
# ----------------LinearSVM----------------
# auc = 0.7935442039309013
# 		------------------------26 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8212586139050861
# ----------------Random Forest----------------
# auc = 0.8057921787739496
# ----------------Logistic----------------
# auc = 0.7811390800957584
# ----------------Stochastic GD----------------
# auc = 0.6879057819793342
# ----------------LinearSVM----------------
# auc = 0.7850348543741544
# 		------------------------27 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8684133515645047
# ----------------Random Forest----------------
# auc = 0.8484504729047793
# ----------------Logistic----------------
# auc = 0.7723928288352736
# ----------------Stochastic GD----------------
# auc = 0.7298156856884138
# ----------------LinearSVM----------------
# auc = 0.7832184676643845
# 		------------------------28 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8566313390769018
# ----------------Random Forest----------------
# auc = 0.8424838832796055
# ----------------Logistic----------------
# auc = 0.7799228559132065
# ----------------Stochastic GD----------------
# auc = 0.7246311876680674
# ----------------LinearSVM----------------
# auc = 0.7957876783340844
# 		------------------------29 components------------------------
# ----------------KNeighbors----------------
# auc = 0.8720510044406807
# ----------------Random Forest----------------
# auc = 0.8666223163439514
# ----------------Logistic----------------
# auc = 0.7861456193110388
# ----------------Stochastic GD----------------
# auc = 0.7430432898537389
# ----------------LinearSVM----------------
# auc = 0.7965998390117995
# 		------------------------30 components------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-fbe80103ee7f> in <module>()
#      28                             ('nca',nca)])
#      29
# ---> 30             nca_pipe.fit(df,df_train)
#      31             nca_pipe.named_steps['nca'].set_params(warm_start=True)
#      32
#
# /usr/local/lib/python3.6/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     352                                  self._log_message(len(self.steps) - 1)):
#     353             if self._final_estimator != 'passthrough':
# --> 354                 self._final_estimator.fit(Xt, y, **fit_params)
#     355         return self
#     356
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_nca.py in fit(self, X, y)
#     191         # Verify inputs X and y and NCA parameters, and transform a copy if
#     192         # needed
# --> 193         X, y, init = self._validate_params(X, y)
#     194
#     195         # Initialize the random generator
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_nca.py in _validate_params(self, X, y)
#     312                                  'be greater than the given data '
#     313                                  'dimensionality ({})!'
# --> 314                                  .format(self.n_components, X.shape[1]))
#     315
#     316         # If warm_start is enabled, check that the inputs are consistent
#
# ValueError: The preferred dimensionality of the projected space `n_components` (30) cannot be greater than the given data dimensionality (29)!

# %% [markdown]
# ### Graphics will come soon

# %% [markdown]
# ### If you don't want to wait, don't execute the cel bellow, just the next one that has a NCA with 2 components

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/creditcard.csv')
X = df.drop(['Time'],axis=1)
y = df['Class']

chunksize = 18000
t0 = time.time()

nca = NeighborhoodComponentsAnalysis(random_state=42,n_components=2)

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33,random_state=42)
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)
list_df = [X_train.loc[i:i+chunksize-1,:] for i in range(0,X_train.shape[0],chunksize)]

for df in list_df:
        df_train=df.pop('Class')
        scaler = StandardScaler()
        nca_pipe = Pipeline([('scaler',scaler),
                        ('nca',nca)])

        nca_pipe.fit(df,df_train)
        nca_pipe.named_steps['nca'].set_params(warm_start=True)
        
X_test = X_test.drop(['Class'],axis=1)
X_train = X_train.drop(['Class'],axis=1)
X_train_transformed=nca_pipe.transform(X_train)
X_test_transformed=nca_pipe.transform(X_test)

model = KNeighborsClassifier(n_jobs=3)
model.fit(X_train_transformed,y_train)
score = auc_score(model,X_test_transformed,y_test)
print('auc =',score)


print('total time taken:',time.time()-t0)

# %%
nca_pipe = load('../models/nca_pipe.pkl')
model = load('../models/model_neighboors_2.pkl')

# %%
nca_pipe
# Out:
# Pipeline(memory=None,
#          steps=[('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('nca',
#                  NeighborhoodComponentsAnalysis(callback=None, init='auto',
#                                                 max_iter=50, n_components=2,
#                                                 random_state=42, tol=1e-05,
#                                                 verbose=0, warm_start=True))],
#          verbose=False)

# %%
model
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=3, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/creditcard.csv')
X = df.drop(['Time','Class'],axis=1)
y = df['Class']
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_transformed = nca_pipe.transform(X)
X_transformed = pd.DataFrame(X_transformed,index=X.index)

X_test_transformed = nca_pipe.transform(X_test)
X_test_transformed = pd.DataFrame(X_test_transformed,index=X_test.index)

# %%
auc_score(model,X_test_transformed,y_test)
# Out:
# 0.7832702973150836

# %%
h = .03  # step size in the mesh

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])


x_min, x_max = X_test_transformed.values[:, 0].min() - 1, X_test_transformed.values[:, 0].max() + 1
y_min, y_max = X_test_transformed.values[:, 1].min() - 1, X_test_transformed.values[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                      np.arange(y_min, y_max, h))


# x_min, x_max = X_transformed.values[:, 0].min() - 1, X_transformed.values[:, 0].max() + 1
# y_min, y_max = X_transformed.values[:, 1].min() - 1, X_transformed.values[:, 1].max() + 1
# xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
#                      np.arange(y_min, y_max, h))

score = auc_score(model,X_test_transformed,y_test)
acu = model.score(X_test_transformed,y_test)
#score = auc_score(model,X_transformed,y)
#acu = model.score(X_transformed,y)

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
#Z = nca_pipe.named_steps['model'].predict(np.c_[xx.ravel(), yy.ravel()])
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(figsize=(14,12))
plt.pcolormesh(xx, yy, Z, cmap=cmap_light, alpha=.8)

# Plot also the training and testing points
plt.scatter(X_test_transformed.values[:, 0], X_test_transformed.values[:, 1], c=y_test, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title('NCA with 2 Components and KNeighbors Classifier',size='xx-large')
plt.xlabel('Feature 1',size='xx-large')
plt.ylabel('Feature 2',size='xx-large')
plt.text(0.9, 0.1, f'AUC = {score:.5f}\nAccuracy = {acu:.5f}', size=15,
          ha='center', va='center', transform=plt.gca().transAxes)
plt.text(0.9, 0.9, 'Red: Not-fraud\nBlue: Fraud', size=15,
          ha='center', va='center', transform=plt.gca().transAxes)
plt.savefig('NCA_2.png')
plt.show()
